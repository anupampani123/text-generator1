# %% [markdown]
# <a href="https://colab.research.google.com/github/anupampani123/text-generator1/blob/main/textgen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#LSTM model for text generation 
#Text generation based on text by nietzche 

import tensorflow as tf 
import numpy as np
path = tf.keras.utils.get_file( 'nietzsche.txt',origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt') 
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 614400/600901 [==============================] - 1s 2us/step
# Corpus length: 600893

# %%
#Steps : 1) extract a fixed length of overlapping characters 
#        2) one-hot encode them (basically the target)
#        3) Input will then be a 3D array (Sequences, maxlen, unique_characters) with corresponding target output 

maxlen=60
step=3
sentences =[] #this holds the sequences
next_chars=[] #Holds the follow up characters - e.g this is a ca_ , so it will hold t 

for i in range(0,len(text)-maxlen,step):    #increment by step 3 : this then his(space), then is(space)a etc.
  sentences.append(text[i:i+maxlen]);
  next_chars.append(text[i+maxlen]);

print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))   #To get unique characters 

char_indices = dict((char, chars.index(char)) for char in chars) #dictionary to map unique characters to their respective index in text

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)    # Input will then be a 3D array (Sequences, maxlen, unique_characters)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)    
#One hot encoding         
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
#Building the LSTM network 
#Simple network - LSTM followed by a dense layer followed by softmax

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(128, input_shape=(maxlen, len(chars)))) 
model.add(tf.keras.layers.Dense(len(chars), activation='softmax'))

# %%
#Since one hot encoding is used, we will use categorical cross-entropy
#Read about the parameters again later
optimizer = tf.keras.optimizers.RMSprop(lr=0.01) 
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
# from the model, the probability distribution of the next character is drawn using the available text 
# reweight the distribution using the softmax temperature 
# sample next character according to new distribution 
# Add the character to the end of the available text 

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

# model.fit(x, y, batch_size=128, epochs=60)
# start_index = random.randint(0, len(text) - maxlen - 1) 
# generated_text = text[start_index: start_index + maxlen] 
# print('--- Generating with seed: "' + generated_text + '"')


for epoch in range(1, 20):
    print('epoch', epoch)
    
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(70):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 17s 7ms/step - loss: 1.9680
# --- Generating with seed: "n, and often think how i can
# still further advance him, and "
# ------ temperature: 0.2
# n, and often think how i can
# still further advance him, and the one for the result to prosesses of the say the expecian of the one
# ------ temperature: 0.5
# r the result to prosesses of the say the expecian of the one more that the instincted of the late the
# essentic in to the graties f
# ------ temperature: 1.0
#  the instincted of the late the
# essentic in to the graties flow of mesterpoatian aracts and hadily is hais of the
# essean of contam
# ------ temperature: 1.2
# terpoatian aracts and hadily is hais of the
# essean of contame of much as to eutice knowc), it the ordon protectiouquously., the ph
# epoch 2
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.6164
# --- Generating with seed: "and certain in our experiences, that man is the rule, nature"
# ------ temperature: 0.2
# and certain in our experiences, that man is the rule, nature of the sense of the strenget of the same to the strong the sumgether
# ------ temperature: 0.5
# nse of the strenget of the same to the strong the sumgether and last for the simely the self-easol come self-case the decistine it
# ------ temperature: 1.0
# or the simely the self-easol come self-case the decistine it he posious and to
# be dis
# upsation whether the priquice of the griedat
# ------ temperature: 1.2
# s and to
# be dis
# upsation whether the priquice of the griedation of yous like. i the denirly godorm"--all nos and reslys recetres,
# epoch 3
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.5271
# --- Generating with seed: "elicit the same imperative from its thousand moral folds
# and"
# ------ temperature: 0.2
# elicit the same imperative from its thousand moral folds
# and conscious conscious to the same to the same to the same to the same t
# ------ temperature: 0.5
#  conscious to the same to the same to the same to the same there assine of the same of the different socially and less to says som
# ------ temperature: 1.0
# e of the same of the different socially and less to says some knowledge to its that weraverer, if
# to callough very places
# and resi
# ------ temperature: 1.2
# e to its that weraverer, if
# to callough very places
# and resiome" taste, "allow toar certaintyful to evert:one ofoei1cus
# out obtani
# epoch 4
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4813
# --- Generating with seed: "all that is now to
# be at an end? and the disenchantment of w"
# ------ temperature: 0.2
# all that is now to
# be at an end? and the disenchantment of what is a man is a property of the sense of the presend the sense of th
# ------ temperature: 0.5
# an is a property of the sense of the presend the sense of the tright and simply in the inoccamiation of a incerned does not it is
# ------ temperature: 1.0
# nd simply in the inoccamiation of a incerned does not it is agan, in o mankind in antarar
# desire--to uc)ans .here
# her laters pamil
# ------ temperature: 1.2
#  mankind in antarar
# desire--to uc)ans .here
# her laters pamily,k),
# man, how choutous between himself at the asmity funstand ebelier
# epoch 5
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4512
# --- Generating with seed: " quite
# different from what it does among protestants--namely"
# ------ temperature: 0.2
#  quite
# different from what it does among protestants--namely and without the simply to the spirit the same to may be a promise the
# ------ temperature: 0.5
# ut the simply to the spirit the same to may be a promise the ngerment
# in the ends all the supposing of the right of the realing as
# ------ temperature: 1.0
# in the ends all the supposing of the right of the realing as painnest to re more into these promiss sgeam must still sheate:
#
# of g
# ------ temperature: 1.2
# to re more into these promiss sgeam must still sheate:
#
# of grades!
# what it
# must
# there greak eavor, invunionatic compoined sifter a
# epoch 6
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4293
# --- Generating with seed: "t, will be, in the mass, skeptical. the question thus
# become"
# ------ temperature: 0.2
# t, will be, in the mass, skeptical. the question thus
# become to says of the same the fact one may be a man and intention the same
# ------ temperature: 0.5
# f the same the fact one may be a man and intention the same the one man when it is not and the belief them he wisheness and arable
# ------ temperature: 1.0
# n when it is not and the belief them he wisheness and arable: but they have hardsmdvesed with a mad which is hart were for wherend
# ------ temperature: 1.2
#  have hardsmdvesed with a mad which is hart were for wherendeed
# and pastery, feyton.
#
# 1 or
# plaho, taken
# piece."
# y     chal desire.
# epoch 7
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4117
# --- Generating with seed: "e men on this earth will do
# like the sun. and we foremost, w"
# ------ temperature: 0.2
# e men on this earth will do
# like the sun. and we foremost, with the expression of the subjection of the superation of the same the
# ------ temperature: 0.5
# pression of the subjection of the superation of the same the same comprehsent and the moder more command the delication of the com
# ------ temperature: 1.0
# rehsent and the moder more command the delication of the comild for them; also evil. xetworing its fullilaticalities of putifilary
# ------ temperature: 1.2
# em; also evil. xetworing its fullilaticalities of putifilary:
# in a morcoli remad himself--wanifting-conacriof manyrtom. inferation
# epoch 8
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3970
# --- Generating with seed: "s extent, the son, who inherits his father's
# calling and get"
# ------ temperature: 0.2
# s extent, the son, who inherits his father's
# calling and gets and such a personal discoses of the spirit of the same the discovere
# ------ temperature: 0.5
#  a personal discoses of the spirit of the same the discoverelvess of one formerly intellects and simplicion, as we must be also an
# ------ temperature: 1.0
# ne formerly intellects and simplicion, as we must be also an, more hypendour in the gane wish ston person not thow
# it is contrigat
# ------ temperature: 1.2
# endour in the gane wish ston person not thow
# it is contrigaties for us       vore only philosophicallsy".
#
#
# nobre rentern forceg "
# epoch 9
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3862
# --- Generating with seed: "ognize in nature the great means of repose for the soul. we
# "
# ------ temperature: 0.2
# ognize in nature the great means of repose for the soul. we
# have the senter the subject the conscience of the subtreants the subtr
# ------ temperature: 0.5
# enter the subject the conscience of the subtreants the subtre its finally the cimbervess--that nothing mention the
# fastinged and t
# ------ temperature: 1.0
# lly the cimbervess--that nothing mention the
# fastinged and the
# gu?med of the nackswaffulness. that is the ad, it is passia by thei
# ------ temperature: 1.2
# of the nackswaffulness. that is the ad, it is passia by their pul is beir judgments and themselves--motive wapde for place of prom
# epoch 10
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3742
# --- Generating with seed: " of himself and then relies upon the authority of others for"
# ------ temperature: 0.2
#  of himself and then relies upon the authority of others for the same state of the strong--the sense of the sense of the sense of
# ------ temperature: 0.5
# state of the strong--the sense of the sense of the sense of the whole of the same still secult have cases this artisted that the e
# ------ temperature: 1.0
# of the same still secult have cases this artisted that the educularity, genle of it great of any mistomner advantage: gungurfpe us
# ------ temperature: 1.2
# , genle of it great of any mistomner advantage: gungurfpe us
# to whom the name.
#
# enistenords
# haf thoughtusk
# of the
# momerno_s,
# even
# epoch 11
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3663
# --- Generating with seed: "l is sought precisely and exclusively in
# what seems dangerou"
# ------ temperature: 0.2
# l is sought precisely and exclusively in
# what seems dangerous the more and consequent and profur the sense of the finer profundati
# ------ temperature: 0.5
#  and consequent and profur the sense of the finer profundation and instince, in the despretain the power remains and any because i
# ------ temperature: 1.0
# tince, in the despretain the power remains and any because in grammat--are among muchorises before the depired and myst, here artd
# ------ temperature: 1.2
# -are among muchorises before the depired and myst, here artdens, in speak of crise,ful, are biolve it is soote
# cheist
# de no more t
# epoch 12
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3581
# --- Generating with seed: "g badly endowed by nature,
# and finally, it is an opportunity"
# ------ temperature: 0.2
# g badly endowed by nature,
# and finally, it is an opportunity of the strength of the sense of the same present and interestion and
# ------ temperature: 0.5
# rength of the sense of the same present and interestion and present and sufficate and the condition of its sense of the noble orde
# ------ temperature: 1.0
# d sufficate and the condition of its sense of the noble order of well religion without yet smapthing
# intrust short
# and )quates.
#
#
#
# ------ temperature: 1.2
# religion without yet smapthing
# intrust short
# and )quates.
#
#
# 6ect, quiesce-dece pridenty envea :ire founding," he son, futurh-exire
# epoch 13
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3529
# --- Generating with seed: " has been surmounted, when europe, rid of this nightmare,
# ca"
# ------ temperature: 0.2
#  has been surmounted, when europe, rid of this nightmare,
# cause of the strong of the subject and soul and man and all the spirit a
# ------ temperature: 0.5
#  strong of the subject and soul and man and all the spirit and instance of the sensed when they hare hon even to have him of the i
# ------ temperature: 1.0
# e of the sensed when they hare hon even to have him of the inference easie of rights" for croble--asdoun it
# is not-neel, hene" hea
# ------ temperature: 1.2
# asie of rights" for croble--asdoun it
# is not-neel, hene" heart this
# -namely, this goodence. for the (romored
# prad soil-canness out
# epoch 14
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3447
# --- Generating with seed: "raight line, no
# true circle, no standard of measurement.
#
# [8"
# ------ temperature: 0.2
# raight line, no
# true circle, no standard of measurement.
#
# [8] and more and still the possessed the spirit the deep the conscience
# ------ temperature: 0.5
#  and still the possessed the spirit the deep the conscience and their moral view to whom every ancient of the superation, and all
# ------ temperature: 1.0
# moral view to whom every ancient of the superation, and all an artist
# contractive to determinarily
# deppine must be mith in one's e
# ------ temperature: 1.2
# contractive to determinarily
# deppine must be mith in one's exist, centuaicial colcess enolu a.
# such a disiherical, d
# intemt, in tr
# epoch 15
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3400
# --- Generating with seed: " wrongly, claim to be designated as
# "tempters." this name it"
# ------ temperature: 0.2
#  wrongly, claim to be designated as
# "tempters." this name itself and the suffering the suffering the suffering and as the superior
# ------ temperature: 0.5
# he suffering the suffering the suffering and as the superioring and and sort and noble out and through all the same betweth of the
# ------ temperature: 1.0
# d sort and noble out and through all the same betweth of the akonical manifest, merely
# only because the jeking
# and  smalm, as meas
# ------ temperature: 1.2
# manifest, merely
# only because the jeking
# and  smalm, as measuly? and, if khowdw. perhaps pl-incertainy, justre.abily processnec ty
# epoch 16
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3348
# --- Generating with seed: "y to have reverence "for the mask,"
# and not to make use of p"
# ------ temperature: 0.2
# y to have reverence "for the mask,"
# and not to make use of problem of the old the sense of the stand the states of the stranges th
# ------ temperature: 0.5
# the old the sense of the stand the states of the stranges the "which was the sensise which seems to a master, and all the do not i
# ------ temperature: 1.0
# as the sensise which seems to a master, and all the do not in so thisse fli-sigbivous only will unuherning used bountmant for it b
# ------ temperature: 1.2
# e fli-sigbivous only will unuherning used bountmant for it be the circumstank which and be-the belowkerty; togas"pes"s of the wort
# epoch 17
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3294
# --- Generating with seed: "are in the habit of doing--he seems to have adopted a
# popula"
# ------ temperature: 0.2
# are in the habit of doing--he seems to have adopted a
# population of the subject to the same the subject the strength of the same t
# ------ temperature: 0.5
# e subject to the same the subject the strength of the same the powerful, and and good temperation of the world of himself of the s
# ------ temperature: 1.0
# l, and and good temperation of the world of himself of the strength.
#
# 2e souchers there are theologite bring that of the reasoned,
# ------ temperature: 1.2
# 2e souchers there are theologite bring that of the reasoned,
# exproseing
# first stups and
# in fact, and aure, araious, obtain vergs.
# epoch 18
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3243
# --- Generating with seed: "ndless
# and impossible modifications--namely, in all his own "
# ------ temperature: 0.2
# ndless
# and impossible modifications--namely, in all his own interpretation of the same the spirit and interpretation of the world
# ------ temperature: 0.5
# tion of the same the spirit and interpretation of the world and are other regarded perhaps hard whoch and for the slave--and whole
# ------ temperature: 1.0
# her regarded perhaps hard whoch and for the slave--and whole life
# ideas than bad imperfities, who formel, of
# meaning and refine po
# ------ temperature: 1.2
# s than bad imperfities, who formel, of
# meaning and refine pogoting ages would thouthjueer all
# time from once preciselying
# of germa
# epoch 19
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3212
# --- Generating with seed: "christian); it is above all things the happiness of repose, "
# ------ temperature: 0.2
# christian); it is above all things the happiness of repose, and the sense of the sense of the sense of the sense of the sense and
# ------ temperature: 0.5
# nse of the sense of the sense of the sense of the sense and to rest only self-existing and quele that the most man and terness and
# ------ temperature: 1.0
# ly self-existing and quele that the most man and terness and nount softerer, and assuming itny, one is, however
# "interprets they a
# ------ temperature: 1.2
# terer, and assuming itny, one is, however
# "interprets they are among time of the same dpendment, and more
# patheoth better in which
